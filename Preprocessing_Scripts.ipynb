# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("Job_desc_cleaned.csv")
df.head()
# Out:
#    Unnamed: 0            Job Id     Experience Qualifications Salary Range  \
# 0           0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K
# 1           1   398454096642776  2 to 12 Years            BCA   $56K-$116K
# 2           2   481640072963533  0 to 12 Years            PhD   $61K-$104K
# 3           3   688192671473044  4 to 11 Years            PhD    $65K-$91K
# 4           4   117057806156508  1 to 12 Years            MBA    $64K-$87K
#
#      location           Country  latitude  longitude  Work Type  ...  \
# 0     Douglas       Isle of Man   54.2361    -4.5481     Intern  ...
# 1    Ashgabat      Turkmenistan   38.9697    59.5563     Intern  ...
# 2       Macao  Macao SAR, China   22.1987   113.5439  Temporary  ...
# 3  Porto-Novo             Benin    9.3077     2.3158  Full-Time  ...
# 4    Santiago             Chile  -35.6751   -71.5429     Intern  ...
#
#                  Contact                     Job Title  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Job Id              0
# Experience          0
# Qualifications      0
# Salary Range        0
# location            0
# Country             0
# latitude            0
# longitude           0
# Work Type           0
# Company Size        0
# Job Posting Date    0
# Preference          0
# Contact Person      0
# Contact             0
# Job Title           0
# Role                0
# Job Portal          0
# Job Description     0
# Benefits            0
# skills              0
# Responsibilities    0
# Company             0
# Company Profile     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Id', 'Experience', 'Qualifications', 'Salary Range',
#        'location', 'Country', 'latitude', 'longitude', 'Work Type',
#        'Company Size', 'Job Posting Date', 'Preference', 'Contact Person',
#        'Contact', 'Job Title', 'Role', 'Job Portal', 'Job Description',
#        'Benefits', 'skills', 'Responsibilities', 'Company', 'Company Profile'],
#       dtype='object')

# %%
df.rename(columns={'Job Id':'Job_Id','Salary Range':'Salary_Range','Work Type':'Work_Type','Company Size':'Company_Size', 'Job Posting Date':'Job_Posting_Date','Contact Person':'Contact_Person','Job Title':'Job Title','Job Portal':'Job_Portal', 'Job Description':'Job_Description','Company Profile':'Company_Profile'},inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0            Job_Id     Experience Qualifications Salary_Range  \
# 0           0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K
# 1           1   398454096642776  2 to 12 Years            BCA   $56K-$116K
# 2           2   481640072963533  0 to 12 Years            PhD   $61K-$104K
# 3           3   688192671473044  4 to 11 Years            PhD    $65K-$91K
# 4           4   117057806156508  1 to 12 Years            MBA    $64K-$87K
#
#      location           Country  latitude  longitude  Work_Type  ...  \
# 0     Douglas       Isle of Man   54.2361    -4.5481     Intern  ...
# 1    Ashgabat      Turkmenistan   38.9697    59.5563     Intern  ...
# 2       Macao  Macao SAR, China   22.1987   113.5439  Temporary  ...
# 3  Porto-Novo             Benin    9.3077     2.3158  Full-Time  ...
# 4    Santiago             Chile  -35.6751   -71.5429     Intern  ...
#
#                  Contact                     Job Title  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job_Id', 'Experience', 'Qualifications', 'Salary_Range',
#        'location', 'Country', 'latitude', 'longitude', 'Work_Type',
#        'Company_Size', 'Job_Posting_Date', 'Preference', 'Contact_Person',
#        'Contact', 'Job Title', 'Role', 'Job_Portal', 'Job_Description',
#        'Benefits', 'skills', 'Responsibilities', 'Company', 'Company_Profile'],
#       dtype='object')

# %%
filtered_df = df[
    (df['Job_Posting_Date'] >= '2021-11-30') & 
    (df['Job_Posting_Date'] <= '2022-03-30')
]

# %%
filtered_df.shape
# Out:
# (266589, 24)

# %%
filtered_df.head()
# Out:
#     Unnamed: 0            Job_Id     Experience Qualifications Salary_Range  \
# 8            8  1680293940995740   2 to 9 Years            BBA   $65K-$102K
# 12          12  1914121205954296  3 to 15 Years            MCA   $65K-$122K
# 14          14  1627539131873813   1 to 9 Years            MCA    $57K-$98K
# 18          18   235216486127884  3 to 12 Years             BA   $55K-$121K
# 20          20   940776147258900  0 to 15 Years         B.Tech   $62K-$120K
#
#     location               Country  latitude  longitude  Work_Type  ...  \
# 8       Male              Maldives    3.2028    73.2207  Temporary  ...
# 12  Kingston               Jamaica   18.1096   -77.2975  Part-Time  ...
# 14  Damascus  Syrian Arab Republic   34.8021    38.9968  Full-Time  ...
# 18     Seoul           North Korea   40.3399   127.5101   Contract  ...
# 20      Baku            Azerbaijan   40.1431    47.5769  Full-Time  ...
#
#                 Contact                   Job Title  \
# ...

# %%
filtered_df=filtered_df[filtered_df['Job_Portal']== "Indeed"]

# %%
filtered_df['Job_Portal'].unique()
# Out:
# array(['Indeed'], dtype=object)

# %%
filtered_df.shape
# Out:
# (10811, 24)

# %%
filtered_df.head()
# Out:
#      Unnamed: 0            Job_Id     Experience Qualifications Salary_Range  \
# 8             8  1680293940995740   2 to 9 Years            BBA   $65K-$102K
# 139         140     2894688809840  2 to 10 Years         M.Tech   $61K-$116K
# 249         250  2106006937289114  0 to 11 Years         B.Tech   $63K-$111K
# 488         490   525281655753384  5 to 10 Years            BCA   $64K-$113K
# 502         504   722184685078158   0 to 9 Years             BA   $59K-$111K
#
#                  location      Country  latitude  longitude  Work_Type  ...  \
# 8                    Male     Maldives    3.2028    73.2207  Temporary  ...
# 139                  Juba  South Sudan    6.8770    31.3070   Contract  ...
# 249  The City of Hamilton      Bermuda   32.3078   -64.7505  Full-Time  ...
# 488               Kampala       Uganda    1.3733    32.2903   Contract  ...
# 502                Banjul       Gambia   13.4432   -15.3101  Temporary  ...
#
# ...

# %%
filtered_df = filtered_df[
    ((filtered_df['Preference'] == 'Male') & (filtered_df['Work_Type'] == 'Contract')) |
    ((filtered_df['Preference'] == 'Female') & (filtered_df['Work_Type'] == 'Full-Time'))
]

# %%
filtered_df.columns
# Out:
# Index(['Unnamed: 0', 'Job_Id', 'Experience', 'Qualifications', 'Salary_Range',
#        'location', 'Country', 'latitude', 'longitude', 'Work_Type',
#        'Company_Size', 'Job_Posting_Date', 'Preference', 'Contact_Person',
#        'Contact', 'Job Title', 'Role', 'Job_Portal', 'Job_Description',
#        'Benefits', 'skills', 'Responsibilities', 'Company', 'Company_Profile'],
#       dtype='object')

# %%
filtered_df.shape
# Out:
# (1437, 24)

# %%
filtered_df=filtered_df[filtered_df['Company'].str.startswith(('M','A','E'))]

# %%
filtered_df.shape
# Out:
# (274, 24)

# %%
filtered_df.head()
# Out:
#        Unnamed: 0            Job_Id     Experience Qualifications  \
# 139           140     2894688809840  2 to 10 Years         M.Tech
# 564           566  2959379509373746  1 to 10 Years            MCA
# 4752         4766   105273840690649   2 to 8 Years         B.Tech
# 6021         6040  1099632186545233  0 to 12 Years          B.Com
# 22954       23026   341462986127413   1 to 9 Years         M.Tech
#
#       Salary_Range    location       Country  latitude  longitude  Work_Type  \
# 139     $61K-$116K        Juba   South Sudan    6.8770    31.3070   Contract
# 564     $55K-$103K     Yaounde      Cameroon    7.3697    12.3547  Full-Time
# 4752     $55K-$93K       Sofia      Bulgaria   42.7339    25.4858  Full-Time
# 6021    $60K-$126K    Pretoria  South Africa  -30.5595    22.9375  Full-Time
# 22954   $60K-$107K  Nouakchott    Mauritania   21.0079   -10.9408  Full-Time
#
#        ...              Contact               Job Title  \
# ...

# %%
filtered_df=filtered_df[filtered_df['Country'].str.startswith(('B'))]

# %%
filtered_df.shape
# Out:
# (18, 24)

# %%
filtered_df.columns
# Out:
# Index(['Unnamed: 0', 'Job_Id', 'Experience', 'Qualifications', 'Salary_Range',
#        'location', 'Country', 'latitude', 'longitude', 'Work_Type',
#        'Company_Size', 'Job_Posting_Date', 'Preference', 'Contact_Person',
#        'Contact', 'Job Title', 'Role', 'Job_Portal', 'Job_Description',
#        'Benefits', 'skills', 'Responsibilities', 'Company', 'Company_Profile'],
#       dtype='object')

# %%
filtered_df=filtered_df.drop('Unnamed: 0',axis=1)

# %%
filtered_df.head(18)
# Out:
#                    Job_Id     Experience Qualifications Salary_Range  \
# 4752      105273840690649   2 to 8 Years         B.Tech    $55K-$93K
# 79682    2025513744541095   3 to 8 Years          B.Com   $58K-$110K
# 323778    930878648224010  5 to 11 Years             BA   $62K-$103K
# 345238   2784102061825931  3 to 15 Years            BBA   $55K-$102K
# 489169    876740280802368  1 to 11 Years            PhD    $61K-$91K
# 564177    795844274320481  3 to 11 Years          M.Com   $56K-$100K
# 630208     58977625235452  4 to 13 Years            BBA   $59K-$104K
# 634812   2951429346127717  1 to 12 Years          M.Com   $60K-$124K
# 648058   2104968349954371  1 to 11 Years            PhD   $65K-$110K
# 683708   2509696427091169  3 to 10 Years          B.Com   $62K-$114K
# 734449   2321912864807784  3 to 13 Years            BCA    $57K-$94K
# 764424    789451209350341   5 to 9 Years            BCA   $58K-$121K
# 958300   1570047941969189  1 to 12 Years         M.Tech    $55K-$83K
# ...

# %%
filtered_df.to_csv("Proj1_data1.csv")

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Job_desc_cleaned.csv")
df.head()
# Out:
#    Unnamed: 0            Job Id     Experience Qualifications Salary Range  \
# 0           0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K
# 1           1   398454096642776  2 to 12 Years            BCA   $56K-$116K
# 2           2   481640072963533  0 to 12 Years            PhD   $61K-$104K
# 3           3   688192671473044  4 to 11 Years            PhD    $65K-$91K
# 4           4   117057806156508  1 to 12 Years            MBA    $64K-$87K
#
#      location           Country  latitude  longitude  Work Type  ...  \
# 0     Douglas       Isle of Man   54.2361    -4.5481     Intern  ...
# 1    Ashgabat      Turkmenistan   38.9697    59.5563     Intern  ...
# 2       Macao  Macao SAR, China   22.1987   113.5439  Temporary  ...
# 3  Porto-Novo             Benin    9.3077     2.3158  Full-Time  ...
# 4    Santiago             Chile  -35.6751   -71.5429     Intern  ...
#
#                  Contact                     Job Title  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Id', 'Experience', 'Qualifications', 'Salary Range',
#        'location', 'Country', 'latitude', 'longitude', 'Work Type',
#        'Company Size', 'Job Posting Date', 'Preference', 'Contact Person',
#        'Contact', 'Job Title', 'Role', 'Job Portal', 'Job Description',
#        'Benefits', 'skills', 'Responsibilities', 'Company', 'Company Profile'],
#       dtype='object')

# %%
df.rename(columns={'Job Id':'Job_Id','Job Title':'Job_Title','Salary Range':'Salary_Range','Work Type':'Work_Type','Company Size':'Company_Size', 'Job Posting Date':'Job_Posting_Date','Contact Person':'Contact_Person','Job Title':'Job Title','Job Portal':'Job_Portal', 'Job Description':'Job_Description','Company Profile':'Company_Profile'},inplace=True)

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df1=df

# %%
df1.columns
# Out:
# Index(['Job_Id', 'Experience', 'Qualifications', 'Salary_Range', 'location',
#        'Country', 'latitude', 'longitude', 'Work_Type', 'Company_Size',
#        'Job_Posting_Date', 'Preference', 'Contact_Person', 'Contact',
#        'Job Title', 'Role', 'Job_Portal', 'Job_Description', 'Benefits',
#        'skills', 'Responsibilities', 'Company', 'Company_Profile'],
#       dtype='object')

# %%
df1.rename(columns={'Job Title':'Job_Title'},inplace=True)

# %%
df1.columns
# Out:
# Index(['Job_Id', 'Experience', 'Qualifications', 'Salary_Range', 'location',
#        'Country', 'latitude', 'longitude', 'Work_Type', 'Company_Size',
#        'Job_Posting_Date', 'Preference', 'Contact_Person', 'Contact',
#        'Job_Title', 'Role', 'Job_Portal', 'Job_Description', 'Benefits',
#        'skills', 'Responsibilities', 'Company', 'Company_Profile'],
#       dtype='object')

# %%
df1.Qualifications.unique()
# Out:
# array(['M.Tech', 'PhD', 'B.Tech'], dtype=object)

# %%
df1=df1[(df1['Qualifications']=='B.Tech')|(df1['Qualifications']=='M.Tech')|(df1['Qualifications']=='PhD')]

# %%
df1.Work_Type.unique()
# Out:
# array(['Full-Time'], dtype=object)

# %%
df1=df1[df1['Work_Type']=='Full-Time']

# %%
df1.shape
# Out:
# (96253, 23)

# %%
df1=df1[df1['Preference']=='Male']

# %%
df1.shape
# Out:
# (32031, 23)

# %%
df2=df1

# %%
df2.shape
# Out:
# (32031, 23)

# %%
df2=df2[df2['Job_Title'].str.startswith('D')]

# %%
df2.shape
# Out:
# (1918, 23)

# %%
df2['Job_Title'].unique()
# Out:
# array(['Data Analyst', 'Database Administrator', 'Data Entry Clerk',
#        'Dental Hygienist', 'Database Developer', 'Data Engineer',
#        'Digital Marketing Specialist', 'Data Scientist'], dtype=object)

# %%
df2=df2[df2['Company_Size']>80000]

# %%
df2.shape
# Out:
# (865, 23)

# %%
df2.Company_Size
# Out:
# 3853       112588
# 4819       108487
# 7539       125176
# 9527        93440
# 13326       83469
#             ...
# 1594899    107954
# 1596247    114439
# 1596591     82206
# 1605715     86211
# 1606438     84143
# Name: Company_Size, Length: 865, dtype: int64

# %%
df2=df2[df2['Contact_Person'].str.startswith('A')]

# %%
df2.shape
# Out:
# (82, 23)

# %%
df1.Contact_Person
# Out:
# 924147    Andrea Kelly
# Name: Contact_Person, dtype: object

# %%
df3=df2

# %%
df3.Job_Portal.unique()
# Out:
# array(['Jobs2Careers', 'Snagajob', 'Dice', 'Internships.com', 'LinkedIn',
#        'CareerBuilder', 'FlexJobs', 'USAJOBS', 'SimplyHired',
#        'ZipRecruiter', 'The Muse', 'Idealist', 'Stack Overflow Jobs',
#        'Monster', 'Indeed', 'Glassdoor'], dtype=object)

# %%
df3.shape
# Out:
# (82, 23)

# %%
df3.Country.unique()
# Out:
# array(['Turkey', 'Northern Mariana Islands', 'USA', 'Yemen', 'Tonga',
#        'Sint Maarten (Dutch part)', 'Bosnia and Herzegovina', 'Gambia',
#        'St. Lucia', 'Venezuela, RB', 'Honduras', 'Slovenia', 'Poland',
#        'Liberia', 'Finland', 'Guyana', 'Cayman Islands', 'Dominica',
#        'Morocco', 'Turks and Caicos Islands', 'Pakistan', 'Cambodia',
#        'Moldova', 'Estonia', 'American Samoa', 'Kosovo', 'Iraq',
#        'Virgin Islands (U.S.)', 'Kyrgyz Republic', 'Fiji', 'Haiti',
#        'Oman', 'Madagascar', 'Uganda', 'UK', 'Benin', 'Uzbekistan',
#        'Brazil', 'West Bank and Gaza', 'Tanzania', 'Albania', 'Gibraltar',
#        'Sao Tome and Principe', 'St. Kitts and Nevis', 'Kazakhstan',
#        'Belarus', 'Burundi', 'UAE', 'Norway', 'Somalia', 'Curacao',
#        'Kiribati', 'Antigua and Barbuda', 'Slovak Republic', 'Sri Lanka',
#        'St. Martin (French part)', 'Jordan', 'Samoa', 'Seychelles',
# ...

# %%
df3.head(10)
# Out:
#                   Job_Id     Experience Qualifications Salary_Range  \
# 15471    989632334672540  3 to 14 Years         B.Tech   $60K-$118K
# 27227   2663917704086896  3 to 15 Years            PhD   $61K-$127K
# 41270    943643635241228  5 to 11 Years         B.Tech   $58K-$100K
# 63196    477161937453753   5 to 9 Years         B.Tech   $62K-$127K
# 93713    939239043428924   3 to 9 Years         B.Tech   $61K-$104K
# 134948  2261078410197472  4 to 12 Years            PhD    $55K-$95K
# 146621  1015809971586188  2 to 15 Years         M.Tech   $64K-$101K
# 172710  1317189631396362   4 to 9 Years         B.Tech    $56K-$90K
# 229448  2539185392932891  5 to 11 Years         M.Tech   $55K-$103K
# 264251   923111591554735  0 to 13 Years            PhD   $58K-$125K
#
#                     location                    Country  latitude  longitude  \
# 15471                 Ankara                     Turkey   38.9637    35.2433
# ...

# %%
df3.to_csv("data2.csv")

# %%
df1.Job_Portal
# Out:
# 924147    Indeed
# Name: Job_Portal, dtype: object

# %%
df1.head()
# Out:
#                   Job_Id    Experience Qualifications Salary_Range  location  \
# 924147  2571132252644696  5 to 9 Years         B.Tech    $57K-$91K  Brasilia
#
#        Country  latitude  longitude  Work_Type  Company_Size  ...  \
# 924147  Brazil   -14.235   -51.9253  Full-Time        131936  ...
#
#                     Contact     Job_Title                  Role Job_Portal  \
# 924147  (735)825-3133x31779  Data Analyst  Data Quality Analyst     Indeed
#
#                                           Job_Description  \
# 924147  Data Quality Analysts ensure the accuracy, com...
#
#                                                  Benefits  \
# 924147  {'Employee Referral Programs, Financial Counse...
#
#                                                    skills  \
# 924147  Data quality assessment and improvement Data p...
#
#                                          Responsibilities  Company  \
# 924147  Ensure data accuracy and quality by identifyin...  Comcast
#
# ...

# %%
df4=df1

# %%
df1.columns
# Out:
# Index(['Job_Id', 'Experience', 'Qualifications', 'Salary_Range', 'location',
#        'Country', 'latitude', 'longitude', 'Work_Type', 'Company_Size',
#        'Job_Posting_Date', 'Preference', 'Contact_Person', 'Contact',
#        'Job_Title', 'Role', 'Job_Portal', 'Job_Description', 'Benefits',
#        'skills', 'Responsibilities', 'Company', 'Company_Profile'],
#       dtype='object')

# %%
df1.Country.unique()
# Out:
# array(['Brazil'], dtype=object)

# %%
df1.shape
# Out:
# (1, 23)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Job_desc_cleaned.csv")
df.head()
# Out:
#    Unnamed: 0            Job Id     Experience Qualifications Salary Range  \
# 0           0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K
# 1           1   398454096642776  2 to 12 Years            BCA   $56K-$116K
# 2           2   481640072963533  0 to 12 Years            PhD   $61K-$104K
# 3           3   688192671473044  4 to 11 Years            PhD    $65K-$91K
# 4           4   117057806156508  1 to 12 Years            MBA    $64K-$87K
#
#      location           Country  latitude  longitude  Work Type  ...  \
# 0     Douglas       Isle of Man   54.2361    -4.5481     Intern  ...
# 1    Ashgabat      Turkmenistan   38.9697    59.5563     Intern  ...
# 2       Macao  Macao SAR, China   22.1987   113.5439  Temporary  ...
# 3  Porto-Novo             Benin    9.3077     2.3158  Full-Time  ...
# 4    Santiago             Chile  -35.6751   -71.5429     Intern  ...
#
#                  Contact                     Job Title  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Id', 'Experience', 'Qualifications', 'Salary Range',
#        'location', 'Country', 'latitude', 'longitude', 'Work Type',
#        'Company Size', 'Job Posting Date', 'Preference', 'Contact Person',
#        'Contact', 'Job Title', 'Role', 'Job Portal', 'Job Description',
#        'Benefits', 'skills', 'Responsibilities', 'Company', 'Company Profile'],
#       dtype='object')

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.rename(columns={'Job Id':'Job_Id','Job Title':'Job_Title','Salary Range':'Salary_Range','Work Type':'Work_Type','Company Size':'Company_Size', 'Job Posting Date':'Job_Posting_Date','Contact Person':'Contact_Person','Job Title':'Job Title','Job Portal':'Job_Portal', 'Job Description':'Job_Description','Company Profile':'Company_Profile'},inplace=True)

# %%
df.columns
# Out:
# Index(['Job_Id', 'Experience', 'Qualifications', 'Salary_Range', 'location',
#        'Country', 'latitude', 'longitude', 'Work_Type', 'Company_Size',
#        'Job_Posting_Date', 'Preference', 'Contact_Person', 'Contact',
#        'Job Title', 'Role', 'Job_Portal', 'Job_Description', 'Benefits',
#        'skills', 'Responsibilities', 'Company', 'Company_Profile'],
#       dtype='object')

# %%
df=df.rename(columns={'Job Title':'Job_Title'})

# %%
df.shape
# Out:
# (1610462, 23)

# %%
df=df[df['Company_Size']<50000]

# %%
df.shape
# Out:
# (493444, 23)

# %%
titles=sorted(df.Job_Title.unique())
print(titles)
# Out:
# ['Account Director', 'Account Executive', 'Account Manager', 'Accountant', 'Administrative Assistant', 'Aerospace Engineer', 'Architect', 'Architectural Designer', 'Art Director', 'Art Teacher', 'Back-End Developer', 'Brand Ambassador', 'Brand Manager', 'Business Analyst', 'Business Development Manager', 'Chemical Analyst', 'Chemical Engineer', 'Civil Engineer', 'Content Writer', 'Copywriter', 'Customer Service Manager', 'Customer Service Representative', 'Customer Success Manager', 'Customer Support Specialist', 'Data Analyst', 'Data Engineer', 'Data Entry Clerk', 'Data Scientist', 'Database Administrator', 'Database Developer', 'Dental Hygienist', 'Digital Marketing Specialist', 'Electrical Designer', 'Electrical Engineer', 'Email Marketing Specialist', 'Environmental Consultant', 'Environmental Engineer', 'Event Coordinator', 'Event Manager', 'Event Planner', 'Executive Assistant', 'Family Lawyer', 'Family Nurse Practitioner', 'Finance Manager', 'Financial Advisor', 'Financial Ana
# ...

# %%
df=df[df['Job_Title']=='Mechanical Engineer']

# %%
df.shape
# Out:
# (4254, 23)

# %%
df.Experience.unique()
# Out:
# array(['4 to 8 Years', '3 to 8 Years', '4 to 14 Years', '0 to 12 Years',
#        '3 to 12 Years', '2 to 15 Years', '1 to 12 Years', '2 to 14 Years',
#        '5 to 15 Years', '1 to 9 Years', '5 to 8 Years', '1 to 11 Years',
#        '5 to 10 Years', '4 to 9 Years', '0 to 13 Years', '3 to 14 Years',
#        '2 to 9 Years', '5 to 14 Years', '3 to 11 Years', '0 to 8 Years',
#        '4 to 15 Years', '1 to 14 Years', '0 to 10 Years', '1 to 8 Years',
#        '3 to 9 Years', '2 to 12 Years', '3 to 10 Years', '5 to 11 Years',
#        '2 to 8 Years', '0 to 11 Years', '1 to 10 Years', '5 to 9 Years',
#        '2 to 11 Years', '1 to 13 Years', '5 to 13 Years', '4 to 10 Years',
#        '2 to 10 Years', '0 to 15 Years', '5 to 12 Years', '4 to 11 Years',
#        '0 to 14 Years', '4 to 12 Years', '3 to 15 Years', '2 to 13 Years',
#        '4 to 13 Years', '0 to 9 Years', '3 to 13 Years', '1 to 15 Years'],
#       dtype=object)

# %%
df.Work_Type.unique()
# Out:
# array(['Temporary', 'Part-Time', 'Contract', 'Full-Time', 'Intern'],
#       dtype=object)

# %%
df=df[(df['Work_Type']=='Part-Time')|(df['Work_Type']=='Full-Time')]

# %%
df.Work_Type.unique()
# Out:
# array(['Part-Time', 'Full-Time'], dtype=object)

# %%
df.shape
# Out:
# (1671, 23)

# %%
df=df[df['Preference']=='Male']

# %%
df.shape
# Out:
# (570, 23)

# %%
df.columns
# Out:
# Index(['Job_Id', 'Experience', 'Qualifications', 'Salary_Range', 'location',
#        'Country', 'latitude', 'longitude', 'Work_Type', 'Company_Size',
#        'Job_Posting_Date', 'Preference', 'Contact_Person', 'Contact',
#        'Job_Title', 'Role', 'Job_Portal', 'Job_Description', 'Benefits',
#        'skills', 'Responsibilities', 'Company', 'Company_Profile'],
#       dtype='object')

# %%
df=df[df['Job_Portal']=='Idealist']

# %%
df.Job_Portal.unique()
# Out:
# array(['Idealist'], dtype=object)

# %%
df.shape
# Out:
# (570, 23)

# %%
df2=df

# %%
def calculate_average(range_value):
    # Remove 'Years' from the string and split by ' to '
    range_value = range_value.replace(' Years', '')
    numbers = list(map(int, range_value.split(' to ')))  # Convert parts to integers
    return sum(numbers) / len(numbers)  # Calculate average

# Apply the function to the 'Experience' column and create a new column
df['Average_Experience'] = df['Experience'].apply(calculate_average)

print(df.Average_Experience)
# Out:
# 4971       6.5
# 5868       6.0
# 10100      7.5
# 11382      8.5
# 14565      6.5
#           ...
# 1598104    5.5
# 1600606    8.0
# 1602849    5.0
# 1605516    7.0
# 1610171    8.0
# Name: Average_Experience, Length: 570, dtype: float64

# %%
df.Salary_Range
# Out:
# 4971       $62K-$130K
# 5868        $64K-$97K
# 10100      $55K-$118K
# 11382       $61K-$98K
# 14565       $61K-$88K
#               ...
# 1598104    $60K-$123K
# 1600606    $64K-$128K
# 1602849     $56K-$84K
# 1605516    $59K-$110K
# 1610171     $62K-$95K
# Name: Salary_Range, Length: 570, dtype: object

# %%
def calculate_salary_average(salary_range):
    # Remove the dollar sign ($) and 'K', then split by '-'
    salary_range = salary_range.replace('$', '').replace('K', '')
    numbers = list(map(int, salary_range.split('-')))  # Convert parts to integers
    return sum(numbers) / len(numbers)  # Calculate average

# Apply the function to the 'Salary Range' column and create a new column
df['Average_Salary'] = df['Salary_Range'].apply(calculate_salary_average)

print(df.Average_Salary)
# Out:
# 4971       96.0
# 5868       80.5
# 10100      86.5
# 11382      79.5
# 14565      74.5
#            ...
# 1598104    91.5
# 1600606    96.0
# 1602849    70.0
# 1605516    84.5
# 1610171    78.5
# Name: Average_Salary, Length: 570, dtype: float64

# %%
df.columns
# Out:
# Index(['Job_Id', 'Experience', 'Qualifications', 'Salary_Range', 'location',
#        'Country', 'latitude', 'longitude', 'Work_Type', 'Company_Size',
#        'Job_Posting_Date', 'Preference', 'Contact_Person', 'Contact',
#        'Job_Title', 'Role', 'Job_Portal', 'Job_Description', 'Benefits',
#        'skills', 'Responsibilities', 'Company', 'Company_Profile',
#        'Average_Experience', 'Average_Salary'],
#       dtype='object')

# %%
df.shape
# Out:
# (570, 25)

# %%
df.to_csv("data3.csv")
